# %%
#import libraries
from bs4 import BeautifulSoup
import requests
from requests_html import HTMLSession
import pandas as pd
import numpy as np
from time import sleep
from random import randint

# %%
#header needs to be added when scrapping amazon for accessibility. Also add referer after header
header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \
(KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.42','Referer': 'https://www.amazon.com/'}

# %%
url = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1'

# %%
#connect to website (response 200 means connection is good)
response = requests.get(url, headers = header)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
#creating an empty list, so that we can append the values
username = []
review_details = []
ratings = []
colour = []

# %%
#storing required data in the variable
reviews = soup.findAll('div', attrs = {'class':'a-section celwidget'})

# %%
for review in reviews:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)

# %%
#store results in a dataframe
reviews = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews
# Out:
#           Username                                             Review  \
# 0          LightCC  Note: This is specific to the Q35 headset with...
# 1      Nhat Nguyen  I've been shopping around for some decent LDAC...
# 2           HJeffK  I am a giant Anker fan. I have owned their cor...
# 3           yuuxno  Well, the sound quality is excelent, but the m...
# 4           HipGuy  I use this headphone to connect to PC and Phon...
# 5  Nick Karstetter  I have been trialing these headphones for the ...
# 6         Weber713  I use these primarily for work. This means a t...
# 7           DLBear  Very happy. I'm not comparing these to the mos...
# 8             Ryan  Comfort and Fit:This product is very comfortab...
# 9          smfabac  I bought  the Q35 after reading the reviews on...
#
#           User Rating         Color
# 0  3.0 out of 5 stars  Color: Black
# 1  5.0 out of 5 stars  Color: Black
# 2  5.0 out of 5 stars   Color: Blue
# 3  4.0 out of 5 stars  Color: Black
# 4  4.0 out of 5 stars  Color: Black
# 5  4.0 out of 5 stars   Color: Blue
# 6  4.0 out of 5 stars  Color: Black
# 7  5.0 out of 5 stars  Color: Black
# 8  4.0 out of 5 stars  Color: Black
# 9  4.0 out of 5 stars  Color: Black

# %%
reviews = reviews.to_csv('reviews1.csv', index = True)

# %% [markdown]
# ### Page 2

# %%
url2 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=2'

#connect to website
response2 = requests.get(url2, headers = header)
soup2 = BeautifulSoup(response2.content, 'html.parser')

# %%
#storing required data in the variable
reviews2 = soup2.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews2:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)

# %%
#store results in a dataframe
reviews2 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews2
# Out:
#                Username                                             Review  \
# 0               LightCC  Note: This is specific to the Q35 headset with...
# 1           Nhat Nguyen  I've been shopping around for some decent LDAC...
# 2                HJeffK  I am a giant Anker fan. I have owned their cor...
# 3                yuuxno  Well, the sound quality is excelent, but the m...
# 4                HipGuy  I use this headphone to connect to PC and Phon...
# 5       Nick Karstetter  I have been trialing these headphones for the ...
# 6              Weber713  I use these primarily for work. This means a t...
# 7                DLBear  Very happy. I'm not comparing these to the mos...
# 8                  Ryan  Comfort and Fit:This product is very comfortab...
# 9               smfabac  I bought  the Q35 after reading the reviews on...
# 10             V Nelson  My old skull candy hesh 2, started acting up a...
# 11               Justin  These sound fantastic. Amazing for getting wor...
# 12          Edward Zhou  The noise cancel is selective i thing to some ...
# 13   Real reviews by me  This is my first set of over the ear noise can...
# 14          Kyle Archer  The Soundcore Life Q35s are an insanely good d...
# 15  The Maintenance Man  Right out of the box, these are amazing!! Qual...
# 16         Erica Larkin  I wanted a good pair of headphones that would ...
# 17             Kevin S.  I wrote out a very long and detailed review, b...
# 18        Rocky Mtn Fam  I've heard great things about Soundcore and th...
# 19        Brian Di Noto  If you want a pair of hood sounding headphones...
#
#            User Rating         Color
# 0   3.0 out of 5 stars  Color: Black
# 1   5.0 out of 5 stars  Color: Black
# 2   5.0 out of 5 stars   Color: Blue
# 3   4.0 out of 5 stars  Color: Black
# 4   4.0 out of 5 stars  Color: Black
# 5   4.0 out of 5 stars   Color: Blue
# 6   4.0 out of 5 stars  Color: Black
# 7   5.0 out of 5 stars  Color: Black
# 8   4.0 out of 5 stars  Color: Black
# 9   4.0 out of 5 stars  Color: Black
# 10  5.0 out of 5 stars   Color: Blue
# 11  5.0 out of 5 stars   Color: Blue
# 12  5.0 out of 5 stars   Color: Blue
# 13  4.0 out of 5 stars   Color: Blue
# 14  5.0 out of 5 stars  Color: Black
# 15  5.0 out of 5 stars   Color: Blue
# 16  5.0 out of 5 stars   Color: Pink
# 17  5.0 out of 5 stars   Color: Blue
# 18  4.0 out of 5 stars   Color: Blue
# 19  4.0 out of 5 stars   Color: Blue

# %%
reviews2 = reviews2.to_csv('reviews2.csv', index = True)

# %% [markdown]
# ### Page 3

# %%
url3 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=3'

#connect to website
response3 = requests.get(url3, headers = header)
soup3 = BeautifulSoup(response3.content, 'html.parser')

# %%
#storing required data in the variable
reviews3 = soup3.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews3:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews3 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews3
# Out:
#                Username                                             Review  \
# 0               LightCC  Note: This is specific to the Q35 headset with...
# 1           Nhat Nguyen  I've been shopping around for some decent LDAC...
# 2                HJeffK  I am a giant Anker fan. I have owned their cor...
# 3                yuuxno  Well, the sound quality is excelent, but the m...
# 4                HipGuy  I use this headphone to connect to PC and Phon...
# 5       Nick Karstetter  I have been trialing these headphones for the ...
# 6              Weber713  I use these primarily for work. This means a t...
# 7                DLBear  Very happy. I'm not comparing these to the mos...
# 8                  Ryan  Comfort and Fit:This product is very comfortab...
# 9               smfabac  I bought  the Q35 after reading the reviews on...
# 10             V Nelson  My old skull candy hesh 2, started acting up a...
# 11               Justin  These sound fantastic. Amazing for getting wor...
# 12          Edward Zhou  The noise cancel is selective i thing to some ...
# 13   Real reviews by me  This is my first set of over the ear noise can...
# 14          Kyle Archer  The Soundcore Life Q35s are an insanely good d...
# 15  The Maintenance Man  Right out of the box, these are amazing!! Qual...
# 16         Erica Larkin  I wanted a good pair of headphones that would ...
# 17             Kevin S.  I wrote out a very long and detailed review, b...
# 18        Rocky Mtn Fam  I've heard great things about Soundcore and th...
# 19        Brian Di Noto  If you want a pair of hood sounding headphones...
# 20              tc54801  I use these headphones mainly for listening to...
# 21                JerMo  I work from home and get tired of buds and oth...
# 22          Kage Goomba  I bough these back in Jan - Beautifully done -...
# 23                   CS  At first I loved these …..but I couldn’t tell ...
# 24      Amazon Customer  I've only used these about 5 days now and I wo...
# 25     Timothy L. Crump  I had just bought Anker Q30 a few weeks ago  a...
# 26              Mike H.  My fourth Anker product.  Q20 and Liberty Pro ...
# 27              Matt M.  I love these headphones! Anker/Soundcore do so...
# 28               sedona  They have excellent noise cancelling but with ...
# 29               Isaura  Immediately fell in love! For the price the so...
#
#            User Rating         Color
# 0   3.0 out of 5 stars  Color: Black
# 1   5.0 out of 5 stars  Color: Black
# 2   5.0 out of 5 stars   Color: Blue
# 3   4.0 out of 5 stars  Color: Black
# 4   4.0 out of 5 stars  Color: Black
# 5   4.0 out of 5 stars   Color: Blue
# 6   4.0 out of 5 stars  Color: Black
# 7   5.0 out of 5 stars  Color: Black
# 8   4.0 out of 5 stars  Color: Black
# 9   4.0 out of 5 stars  Color: Black
# 10  5.0 out of 5 stars   Color: Blue
# 11  5.0 out of 5 stars   Color: Blue
# 12  5.0 out of 5 stars   Color: Blue
# 13  4.0 out of 5 stars   Color: Blue
# 14  5.0 out of 5 stars  Color: Black
# 15  5.0 out of 5 stars   Color: Blue
# 16  5.0 out of 5 stars   Color: Pink
# 17  5.0 out of 5 stars   Color: Blue
# 18  4.0 out of 5 stars   Color: Blue
# 19  4.0 out of 5 stars   Color: Blue
# 20  5.0 out of 5 stars   Color: Blue
# 21  5.0 out of 5 stars  Color: Black
# 22  5.0 out of 5 stars  Color: Black
# 23  5.0 out of 5 stars   Color: Pink
# 24  5.0 out of 5 stars  Color: Black
# 25  5.0 out of 5 stars   Color: Blue
# 26  5.0 out of 5 stars   Color: Blue
# 27  5.0 out of 5 stars   Color: Pink
# 28  4.0 out of 5 stars   Color: Pink
# 29  5.0 out of 5 stars  Color: Black

# %%
#save file to csv
reviews3 = reviews3.to_csv('reviews3.csv', index = True)

# %% [markdown]
# ### Page 4

# %%
url4 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=4'

#connect to website
response4 = requests.get(url4, headers = header)
soup4 = BeautifulSoup(response4.content, 'html.parser')

# %%
#storing required data in the variable
reviews4 = soup4.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews4:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews4 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews4
# Out:
#                Username                                             Review  \
# 0               LightCC  Note: This is specific to the Q35 headset with...
# 1           Nhat Nguyen  I've been shopping around for some decent LDAC...
# 2                HJeffK  I am a giant Anker fan. I have owned their cor...
# 3                yuuxno  Well, the sound quality is excelent, but the m...
# 4                HipGuy  I use this headphone to connect to PC and Phon...
# 5       Nick Karstetter  I have been trialing these headphones for the ...
# 6              Weber713  I use these primarily for work. This means a t...
# 7                DLBear  Very happy. I'm not comparing these to the mos...
# 8                  Ryan  Comfort and Fit:This product is very comfortab...
# 9               smfabac  I bought  the Q35 after reading the reviews on...
# 10             V Nelson  My old skull candy hesh 2, started acting up a...
# 11               Justin  These sound fantastic. Amazing for getting wor...
# 12          Edward Zhou  The noise cancel is selective i thing to some ...
# 13   Real reviews by me  This is my first set of over the ear noise can...
# 14          Kyle Archer  The Soundcore Life Q35s are an insanely good d...
# 15  The Maintenance Man  Right out of the box, these are amazing!! Qual...
# 16         Erica Larkin  I wanted a good pair of headphones that would ...
# 17             Kevin S.  I wrote out a very long and detailed review, b...
# 18        Rocky Mtn Fam  I've heard great things about Soundcore and th...
# 19        Brian Di Noto  If you want a pair of hood sounding headphones...
# 20              tc54801  I use these headphones mainly for listening to...
# 21                JerMo  I work from home and get tired of buds and oth...
# 22          Kage Goomba  I bough these back in Jan - Beautifully done -...
# 23                   CS  At first I loved these …..but I couldn’t tell ...
# 24      Amazon Customer  I've only used these about 5 days now and I wo...
# 25     Timothy L. Crump  I had just bought Anker Q30 a few weeks ago  a...
# 26              Mike H.  My fourth Anker product.  Q20 and Liberty Pro ...
# 27              Matt M.  I love these headphones! Anker/Soundcore do so...
# 28               sedona  They have excellent noise cancelling but with ...
# 29               Isaura  Immediately fell in love! For the price the so...
# 30             Hannah Q  So I had trouble charging it at first. I thoug...
# 31        David Esteban  These headphones feel and sound really good. I...
# 32                Steve  ::Update 10-27-21::After the review posted I t...
# 33           Greg Klema  They are very comfortable and the factory says...
# 34              Patrick  I used these recently for an international fli...
# 35                  Kat  I bought these to see if they would be better ...
# 36             Alisia h  These things right here are fantastic. Wireles...
# 37             J. Wylie  These headphones sounded really good. The nois...
# 38      Kindle Customer  I have had these headphones for a while now an...
# 39         Jean Koegler  Good build, Comfortable, and with the EQ app t...
#
#            User Rating         Color
# 0   3.0 out of 5 stars  Color: Black
# 1   5.0 out of 5 stars  Color: Black
# 2   5.0 out of 5 stars   Color: Blue
# 3   4.0 out of 5 stars  Color: Black
# 4   4.0 out of 5 stars  Color: Black
# 5   4.0 out of 5 stars   Color: Blue
# 6   4.0 out of 5 stars  Color: Black
# 7   5.0 out of 5 stars  Color: Black
# 8   4.0 out of 5 stars  Color: Black
# 9   4.0 out of 5 stars  Color: Black
# 10  5.0 out of 5 stars   Color: Blue
# 11  5.0 out of 5 stars   Color: Blue
# 12  5.0 out of 5 stars   Color: Blue
# 13  4.0 out of 5 stars   Color: Blue
# 14  5.0 out of 5 stars  Color: Black
# 15  5.0 out of 5 stars   Color: Blue
# 16  5.0 out of 5 stars   Color: Pink
# 17  5.0 out of 5 stars   Color: Blue
# 18  4.0 out of 5 stars   Color: Blue
# 19  4.0 out of 5 stars   Color: Blue
# 20  5.0 out of 5 stars   Color: Blue
# 21  5.0 out of 5 stars  Color: Black
# 22  5.0 out of 5 stars  Color: Black
# 23  5.0 out of 5 stars   Color: Pink
# 24  5.0 out of 5 stars  Color: Black
# 25  5.0 out of 5 stars   Color: Blue
# 26  5.0 out of 5 stars   Color: Blue
# 27  5.0 out of 5 stars   Color: Pink
# 28  4.0 out of 5 stars   Color: Pink
# 29  5.0 out of 5 stars  Color: Black
# 30  4.0 out of 5 stars   Color: Blue
# 31  4.0 out of 5 stars   Color: Blue
# 32  4.0 out of 5 stars   Color: Pink
# 33  4.0 out of 5 stars   Color: Blue
# 34  5.0 out of 5 stars  Color: Black
# 35  5.0 out of 5 stars  Color: Black
# 36  5.0 out of 5 stars  Color: Black
# 37  3.0 out of 5 stars   Color: Blue
# 38  5.0 out of 5 stars  Color: Black
# 39  5.0 out of 5 stars  Color: Black

# %% [markdown]
# ### Page 5

# %%
url5 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=5'

#connect to website
response5 = requests.get(url5, headers = header)
soup5 = BeautifulSoup(response5.content, 'html.parser')

# %%
#storing required data in the variable
reviews5 = soup5.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews5:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews5 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews5.tail(5)
# Out:
#         Username                                             Review  \
# 45    Technovore  They do the job well to block out airplane noi...
# 46  LedHeadBruce  I actually like the controls on these cans and...
# 47     Nathan D.  Pros:* These headphones are very comfortable a...
# 48       Kelly R                      The media could not be loa...
# 49    Printmaven  These are great at noise cancellation and volu...
#
#            User Rating         Color
# 45  4.0 out of 5 stars   Color: Blue
# 46  4.0 out of 5 stars  Color: Black
# 47  4.0 out of 5 stars   Color: Blue
# 48  5.0 out of 5 stars   Color: Pink
# 49  4.0 out of 5 stars  Color: Black

# %%
#save file to csv
reviews5 = reviews5.to_csv('reviews5.csv', index = True)

# %% [markdown]
# ### Page 6

# %%
url6 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=6'

#connect to website
response6 = requests.get(url6, headers = header)
soup6 = BeautifulSoup(response6.content, 'html.parser')

# %%
#storing required data in the variable
reviews6 = soup6.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews6:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews6 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews6.tail(5)
# Out:
#                   Username                                             Review  \
# 55                      MP  I really wanted to like these headphones, and ...
# 56  Scott Veronica Richard  Sound quality and noise canceling are what I w...
# 57               Michael K  First of all, I like these headphones.  I like...
# 58            Kevin Conlon  These sound great.They get plenty loud. The no...
# 59          Matthew Farris  I really enjoy the customization of the audio....
#
#            User Rating         Color
# 55  2.0 out of 5 stars   Color: Blue
# 56  5.0 out of 5 stars   Color: Blue
# 57  4.0 out of 5 stars  Color: Black
# 58  5.0 out of 5 stars  Color: Black
# 59  5.0 out of 5 stars  Color: Black

# %%
#save file to csv
reviews6 = reviews6.to_csv('reviews6.csv', index = True)

# %% [markdown]
# ### Page 7

# %%
url7 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=7'

#connect to website
response7 = requests.get(url7, headers = header)
soup7 = BeautifulSoup(response6.content, 'html.parser')

# %%
#storing required data in the variable
reviews7 = soup7.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews7:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews7 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews7.tail(5)
# Out:
#                   Username                                             Review  \
# 65                      MP  I really wanted to like these headphones, and ...
# 66  Scott Veronica Richard  Sound quality and noise canceling are what I w...
# 67               Michael K  First of all, I like these headphones.  I like...
# 68            Kevin Conlon  These sound great.They get plenty loud. The no...
# 69          Matthew Farris  I really enjoy the customization of the audio....
#
#            User Rating         Color
# 65  2.0 out of 5 stars   Color: Blue
# 66  5.0 out of 5 stars   Color: Blue
# 67  4.0 out of 5 stars  Color: Black
# 68  5.0 out of 5 stars  Color: Black
# 69  5.0 out of 5 stars  Color: Black

# %%
#save file to csv
reviews7 = reviews7.to_csv('reviews7.csv', index = True)

# %% [markdown]
# ### Page 8

# %%
url8 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=8'

#connect to website
response8 = requests.get(url8, headers = header)
soup8 = BeautifulSoup(response8.content, 'html.parser')

# %%
#storing required data in the variable
reviews8 = soup8.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews8:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews8 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews8.tail(5)
# Out:
#            Username                                             Review  \
# 85  Jennifer Bonham  It works well! Noise cancellation made me feel...
# 86             Alex  It's been a little over two months of wearing ...
# 87          pb_9876  I found these headphones to be very good for t...
# 88         LillaBee  I originally reviewed these with negative feed...
# 89              Lex                             Nothing great head set
#
#            User Rating         Color
# 85  4.0 out of 5 stars   Color: Blue
# 86  3.0 out of 5 stars  Color: Black
# 87  4.0 out of 5 stars   Color: Pink
# 88  4.0 out of 5 stars   Color: Pink
# 89  4.0 out of 5 stars   Color: Blue

# %%
#save file to csv
reviews8 = reviews8.to_csv('reviews8.csv', index = True)

# %% [markdown]
# ### Page 9

# %%
url9 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=9'

#connect to website
response9 = requests.get(url9, headers = header)
soup9 = BeautifulSoup(response9.content, 'html.parser')

# %%
#storing required data in the variable
reviews9 = soup9.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews9:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews9 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews9.tail(5)
# Out:
#              Username                                             Review  \
# 95             BillyG  The earpieces are very comfortable and fit ove...
# 96        ricki green        does what it says on the pack, great value.
# 97        Abracadabra  Much better  sound than I expected, great for ...
# 98  Harriram Oumadath  So I've adjusting my review having put the pro...
# 99    Matthew P Smith  I have owned a pair of Soundcore Q20s for 2 ye...
#
#            User Rating         Color
# 95  5.0 out of 5 stars  Color: Black
# 96  5.0 out of 5 stars   Color: Blue
# 97  5.0 out of 5 stars   Color: Blue
# 98  5.0 out of 5 stars   Color: Blue
# 99  4.0 out of 5 stars  Color: Black

# %%
#save file to csv
reviews9 = reviews9.to_csv('reviews9.csv', index = True)

# %% [markdown]
# ### Page 10

# %%
url10 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=10'

#connect to website
response10 = requests.get(url10, headers = header)
soup10 = BeautifulSoup(response10.content, 'html.parser')

# %%
#storing required data in the variable
reviews10 = soup10.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews10:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews10 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews10.tail(5)
# Out:
#                Username                                             Review  \
# 105          BarelyPaid  The noise canceling works well, and doesn't ma...
# 106  Burley J Baker Jr.  Very impressive sound quality for the price.  ...
# 107           Steven H.  Sound quality is great and clear (with custom ...
# 108  Peter Buompensiero  I had previously owned a couple of pairs of Be...
# 109       Evan & Hannah  These headphones are impressive when you consi...
#
#             User Rating         Color
# 105  5.0 out of 5 stars  Color: Black
# 106  4.0 out of 5 stars  Color: Black
# 107  4.0 out of 5 stars   Color: Blue
# 108  4.0 out of 5 stars  Color: Black
# 109  4.0 out of 5 stars   Color: Blue

# %%
#save file to csv
reviews10 = reviews10.to_csv('reviews10.csv', index = True)

# %% [markdown]
# ### Page 11

# %%
url11 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=11'

#connect to website
response11 = requests.get(url11, headers = header)
soup11 = BeautifulSoup(response11.content, 'html.parser')

# %%
#storing required data in the variable
reviews11 = soup11.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews11:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews11 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews11.tail(5)
# Out:
#              Username                                             Review  \
# 155         Max Sadik  I am beyond impressed with how good these are ...
# 156  Gretchen Jackson  I bought this for the high quality mic. It has...
# 157   Michael Mercier  These headphones have a warm, detailed sound t...
# 158             Ander  Bought this headphones for my girlfriend on pi...
# 159            Dmitry  I bought these because I didn't want to spend ...
#
#             User Rating        Color
# 155  5.0 out of 5 stars  Color: Blue
# 156  3.0 out of 5 stars  Color: Blue
# 157  4.0 out of 5 stars  Color: Blue
# 158  5.0 out of 5 stars  Color: Pink
# 159  4.0 out of 5 stars  Color: Blue

# %%
#save file to csv
reviews11 = reviews11.to_csv('reviews11.csv', index = True)

# %% [markdown]
# ### Page 12

# %%
url12 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=12'

# %%
#storing required data in the variable
reviews12 = soup12.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews12:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews12 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews12.tail(5)
# Out:
#                  Username                                             Review  \
# 145                 Myron  I replaced my Artis 7 for these because they a...
# 146  chance orion mclaren  Everything is good once you equalize everythin...
# 147      Indraneel Phadke  Writing this review 14 months after I purchase...
# 148                 Vicky  The sound on these is awesome! I was thinking ...
# 149                Omerta  These are amazing headphones w all the bells a...
#
#             User Rating         Color
# 145  4.0 out of 5 stars  Color: Black
# 146  3.0 out of 5 stars  Color: Black
# 147  3.0 out of 5 stars   Color: Blue
# 148  4.0 out of 5 stars  Color: Black
# 149  5.0 out of 5 stars   Color: Blue

# %% [markdown]
# ### Page 13

# %%
url13 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=13'

#connect to website
response13 = requests.get(url13, headers = header)
soup13 = BeautifulSoup(response13.content, 'html.parser')

# %%
#storing required data in the variable
reviews13 = soup13.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews13:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews13 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews13.tail(5)
# Out:
#            Username                                             Review  \
# 165          angelo  My 3-year-old headphone (taotronic) is now bro...
# 166    Don Van Atta  The basic sound quality seems very good, and t...
# 167       Garfcadet  I bought these Q35s for my wife as an experime...
# 168  Andrew Mahabee  Day 1:I would like to preface this review by s...
# 169  Jonathan Hjelm  I own a pair of the Q20 headphones - which I h...
#
#             User Rating         Color
# 165  3.0 out of 5 stars   Color: Blue
# 166  3.0 out of 5 stars  Color: Black
# 167  5.0 out of 5 stars  Color: Black
# 168  5.0 out of 5 stars  Color: Black
# 169  3.0 out of 5 stars  Color: Black

# %%
#save file to csv
reviews13 = reviews13.to_csv('reviews13.csv', index = True)

# %% [markdown]
# ### Page 14

# %%
url14 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=14'

#connect to website
response14 = requests.get(url14, headers = header)
soup14 = BeautifulSoup(response14.content, 'html.parser')

# %%
#storing required data in the variable
reviews14 = soup14.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews14:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews14 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews14.tail(5)
# Out:
#             Username                                             Review  \
# 175         Old Frog  I was an early adopter of these phones receivi...
# 176           Rachel  As a med student, I was so excited to get thes...
# 177        Wordimont  I've been using these regularly for about 11 m...
# 178  marissa sanches  I like these. I had to strech them out a bit b...
# 179          Tony H.  I have a lot of Anker products because they al...
#
#             User Rating         Color
# 175  5.0 out of 5 stars   Color: Blue
# 176  3.0 out of 5 stars   Color: Pink
# 177  2.0 out of 5 stars  Color: Black
# 178  5.0 out of 5 stars   Color: Blue
# 179  4.0 out of 5 stars   Color: Blue

# %%
#save file to csv
reviews14 = reviews14.to_csv('reviews14.csv', index = True)

# %% [markdown]
# ### Page 15

# %%
url15 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=15'

#connect to website
response15 = requests.get(url15, headers = header)
soup15 = BeautifulSoup(response15.content, 'html.parser')

# %%
#storing required data in the variable
reviews15 = soup15.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews15:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews15 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews15.tail(5)
# Out:
#             Username                                             Review  \
# 185  Amazon Customer  I was extremely impressed with these cans. For...
# 186            Delia  Got these during Prime Day and they were less ...
# 187  Matthew Addison  These headphones worked really well, but for m...
# 188    Julie Stevens  I got these based on the specs of 4 microphone...
# 189   Thomas Plummer  Oh, I really like the product. Works well and ...
#
#             User Rating         Color
# 185  5.0 out of 5 stars  Color: Black
# 186  5.0 out of 5 stars   Color: Blue
# 187  4.0 out of 5 stars  Color: Black
# 188  3.0 out of 5 stars   Color: Pink
# 189  5.0 out of 5 stars  Color: Black

# %%
#save file to csv
reviews15 = reviews15.to_csv('reviews15.csv', index = True)

# %% [markdown]
# ### Page 16

# %%
url16 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=16'

#connect to website
response16 = requests.get(url16, headers = header)
soup16 = BeautifulSoup(response16.content, 'html.parser')

# %%
#storing required data in the variable
reviews16 = soup16.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews16:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews16 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews16.tail(5)
# Out:
#        Username                                             Review  \
# 5    Adam sawas  Noice cancelation is really good. It’s not lik...
# 6  Eric Averitt  Solid budget headphones. You could absolutely ...
# 7      Keith S.  Ok so let me start by saying this is the first...
# 8        london                                   beautiful so far
# 9    Lina Isaza                      Very pleased with my purchase
#
#           User Rating         Color
# 5  5.0 out of 5 stars   Color: Blue
# 6  4.0 out of 5 stars  Color: Black
# 7  5.0 out of 5 stars  Color: Black
# 8  5.0 out of 5 stars   Color: Pink
# 9  5.0 out of 5 stars   Color: Pink

# %%
#save file to csv
reviews16 = reviews16.to_csv('reviews15.csv', index = True)

# %% [markdown]
# ### Page 17

# %%
url17 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=17'

#connect to website
response17 = requests.get(url17, headers = header)
soup17 = BeautifulSoup(response17.content, 'html.parser')

# %%
#storing required data in the variable
reviews17 = soup17.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews17:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews17 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews17.tail(5)
# Out:
#             Username                                             Review  \
# 15               Ron  I was disappointed in these. The sound was ver...
# 16  Michael Stauffer  For about half of the best noise-cancelling he...
# 17             McGuy  First my bias.  I am a fan of Anker.  It is on...
# 18  TIFFANY S. HUERD  When I first purchased this headphone set I wa...
# 19              Eric  These are super comfortable for me, I have a b...
#
#            User Rating        Color
# 15  4.0 out of 5 stars  Color: Blue
# 16  5.0 out of 5 stars  Color: Blue
# 17  4.0 out of 5 stars  Color: Blue
# 18  5.0 out of 5 stars  Color: Pink
# 19  4.0 out of 5 stars  Color: Blue

# %%
#save file to csv
reviews17 = reviews17.to_csv('reviews17.csv', index = True)

# %% [markdown]
# ### Page 18

# %%
url18 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=18'

#connect to website
response18 = requests.get(url18, headers = header)
soup18 = BeautifulSoup(response18.content, 'html.parser')

# %%
#storing required data in the variable
reviews18 = soup18.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews18:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews18 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews18.tail(5)
# Out:
#              Username                                             Review  \
# 25                 JB  I had a pair of Q20 for about a year. I like t...
# 26                 MC  I bought  headphones so that I could enjoy mus...
# 27    Joshua Grgurich  Noise canceling isn’t great but what do you ex...
# 28  Jeffrey A. Backer  Works great when I am mowing. I do not have to...
# 29            Michael  These are my first noise cancelling headphones...
#
#            User Rating         Color
# 25  3.0 out of 5 stars   Color: Blue
# 26  5.0 out of 5 stars   Color: Blue
# 27  4.0 out of 5 stars  Color: Black
# 28  5.0 out of 5 stars  Color: Black
# 29  5.0 out of 5 stars  Color: Black

# %%
#save file to csv
reviews18 = reviews18.to_csv('reviews18.csv', index = True)

# %% [markdown]
# ### Page 19

# %%
url19 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=19'

#connect to website
response19 = requests.get(url19, headers = header)
soup19 = BeautifulSoup(response19.content, 'html.parser')

# %%
#storing required data in the variable
reviews19 = soup19.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews19:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews19 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews19.tail(5)
# Out:
#           Username                                             Review  \
# 35             Dan  I love the audio quality, the clean  bass resp...
# 36    Amazon Buyer  Good headphones for iPhone bluetooth connectio...
# 37           TBolt  So I started looking at headphones in November...
# 38  "staceyheaven"                               Great for it’s value
# 39         Azráh K  Sound quality is really good, makes tracks mor...
#
#            User Rating         Color
# 35  5.0 out of 5 stars   Color: Blue
# 36  3.0 out of 5 stars   Color: Blue
# 37  5.0 out of 5 stars   Color: Blue
# 38  4.0 out of 5 stars  Color: Black
# 39  3.0 out of 5 stars   Color: Blue

# %%
#save file to csv
reviews19 = reviews19.to_csv('reviews19.csv', index = True)

# %% [markdown]
# ### Page 20

# %%
url20 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=20'

#connect to website
response20 = requests.get(url20, headers = header)
soup20 = BeautifulSoup(response20.content, 'html.parser')

# %%
#storing required data in the variable
reviews20 = soup20.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews20:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews20 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews20.tail(5)
# Out:
#             Username                                             Review  \
# 45           misterb  So far I have liked everything about this head...
# 46      Rick Sanchez  I needed good headphones with bass. I almost b...
# 47        Clare ~ TX  Very comfortable, sound quality excellent , gr...
# 48          R. Gomez  Every product from Anker/Soundcore simply gets...
# 49  tantric circuits  I have Soundcore pods and one of their Bluetoo...
#
#            User Rating         Color
# 45  5.0 out of 5 stars  Color: Black
# 46  5.0 out of 5 stars   Color: Blue
# 47  5.0 out of 5 stars   Color: Blue
# 48  5.0 out of 5 stars   Color: Blue
# 49  4.0 out of 5 stars  Color: Black

# %%
#save file to csv
reviews20 = reviews20.to_csv('reviews20.csv', index = True)

# %% [markdown]
# ### Page 21

# %%
url21 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=21'

#connect to website
response21 = requests.get(url21, headers = header)
soup21 = BeautifulSoup(response21.content, 'html.parser')

# %%
#storing required data in the variable
reviews21 = soup21.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews21:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews21 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews21.tail(5)
# Out:
#                Username                                             Review  \
# 55             Jonathan  Simply awesome wireless noise cancelling headp...
# 56  Stephen Dale Spicer  Update:After some research, I found that I can...
# 57              clay282  I guess I don't fit the main demographic of he...
# 58        Mark Albrecht  Awesome noice cancelation, comfortable sound q...
# 59     Lance Williamson  Ordered a white and got a kinda ugly... purple...
#
#            User Rating         Color
# 55  5.0 out of 5 stars  Color: Black
# 56  4.0 out of 5 stars   Color: Blue
# 57  2.0 out of 5 stars   Color: Blue
# 58  4.0 out of 5 stars  Color: Black
# 59  4.0 out of 5 stars   Color: Pink

# %%
#save file to csv
reviews21 = reviews21.to_csv('reviews21.csv', index = True)

# %% [markdown]
# ### Page 22

# %%
url22 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=22'

#connect to website
response22 = requests.get(url22, headers = header)
soup22 = BeautifulSoup(response22.content, 'html.parser')

# %%
#storing required data in the variable
reviews22 = soup22.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews22:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews22 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews22.tail(5)
# Out:
#         Username                                             Review  \
# 65      Ernest B  My VERY expensive Sony WH-1000XM4 headphones l...
# 66  KRISHNA TEJA  Headset is quiet good, but most of the time vo...
# 67           Ren  Had the Q30. They cut out from time to time. O...
# 68      Courtney  I purchased these solely for use when travelin...
# 69       Nicole   Great prosciutto for the price. Always happy t...
#
#            User Rating         Color
# 65  5.0 out of 5 stars  Color: Black
# 66  3.0 out of 5 stars   Color: Blue
# 67  5.0 out of 5 stars  Color: Black
# 68  3.0 out of 5 stars   Color: Blue
# 69  5.0 out of 5 stars   Color: Pink

# %% [markdown]
# ### Page 23

# %%
url23 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=23'

#connect to website
response23 = requests.get(url23, headers = header)
soup23 = BeautifulSoup(response23.content, 'html.parser')

# %%
#storing required data in the variable
reviews23 = soup23.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews23:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews23 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews23.tail(5)
# Out:
#              Username                                             Review  \
# 75  Anonymous Shopper  I bought these headphones on a whim because th...
# 76              Hazel  I have had these for over a year and a half, a...
# 77             adrien  Decent overall sound for the price point (7/10...
# 78              Shyam  Update:Anker contacted me about my comment on ...
# 79         Steve Cook  I use these exclusively for Zoom/Teams calls i...
#
#            User Rating         Color
# 75  5.0 out of 5 stars   Color: Blue
# 76  5.0 out of 5 stars   Color: Pink
# 77  3.0 out of 5 stars   Color: Blue
# 78  4.0 out of 5 stars   Color: Blue
# 79  5.0 out of 5 stars  Color: Black

# %% [markdown]
# ### Page 24

# %%
url24 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=24'

#connect to website
response24 = requests.get(url24, headers = header)
soup24 = BeautifulSoup(response24.content, 'html.parser')

# %%
#storing required data in the variable
reviews24 = soup24.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews24:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews24 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews24.tail(5)
# Out:
#            Username                                             Review  \
# 85  Brice E. Carson  Mostly bought these to work with my computer s...
# 86        Cody Mort  The default EQ is pretty terrible. I had to cr...
# 87         Boarhind  I've always been happy with all my Soundcore p...
# 88          JMorfit  Fall off head too frequently & noise cancel co...
# 89   David Kastning  I like these headphones. I wear BTE hearing ai...
#
#            User Rating         Color
# 85  5.0 out of 5 stars   Color: Blue
# 86  4.0 out of 5 stars   Color: Blue
# 87  5.0 out of 5 stars  Color: Black
# 88  3.0 out of 5 stars   Color: Blue
# 89  5.0 out of 5 stars  Color: Black

# %% [markdown]
# ### Page 25

# %%
url25 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=25'

#connect to website
response25 = requests.get(url25, headers = header)
soup25 = BeautifulSoup(response25.content, 'html.parser')

# %%
#storing required data in the variable
reviews25 = soup25.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews25:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews25 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews25.tail(5)
# Out:
#        Username                                             Review  \
# 95    Otniel C.  The Features are an improvement over the life ...
# 96     Whitneyg  I love these headphones. They eliminated the h...
# 97         Dean  Great product and at a great price!  First imp...
# 98     Nse Etim  I'll recommend getting a Samsung or Apple USB ...
# 99  Karen Shore  Even a person who isn't totally tech savvy can...
#
#            User Rating        Color
# 95  3.0 out of 5 stars  Color: Blue
# 96  5.0 out of 5 stars  Color: Pink
# 97  5.0 out of 5 stars  Color: Blue
# 98  5.0 out of 5 stars  Color: Blue
# 99  5.0 out of 5 stars  Color: Blue

# %%
#save file to csv
reviews25 = reviews25.to_csv('reviews25.csv', index = True)

# %% [markdown]
# ### Page 26

# %%
url26 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=26'

#connect to website
response26 = requests.get(url26, headers = header)
soup26 = BeautifulSoup(response26.content, 'html.parser')

# %%
#storing required data in the variable
reviews26 = soup26.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews26:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews26 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews26.tail(5)
# Out:
#            Username                                             Review  \
# 105  clark a scates  This model, is far superior to a previous mode...
# 106     kevin reich  Having Bluetooth and 3.5mm make these unstoppa...
# 107          Mufasa  Bought these on recommendation from my daughte...
# 108       Andrea O.  Way better than I expected. A little sweat at ...
# 109  Kevin R. Wojda  Love these. Not a huge audiophile, but wanted ...
#
#             User Rating         Color
# 105  5.0 out of 5 stars   Color: Pink
# 106  5.0 out of 5 stars  Color: Black
# 107  4.0 out of 5 stars   Color: Blue
# 108  5.0 out of 5 stars  Color: Black
# 109  5.0 out of 5 stars   Color: Blue

# %% [markdown]
# ### Page 27

# %%
url27 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=27'

#connect to website
response27 = requests.get(url27, headers = header)
soup27 = BeautifulSoup(response27.content, 'html.parser')

# %%
#storing required data in the variable
reviews27 = soup27.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews27:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews27 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews27.tail(5)
# Out:
#         Username                                             Review  \
# 115           BG  Headphones sounded great for me- but only when...
# 116     Steve808                                               None
# 117  R. Hiestand  Work as expected.  These work great with my ph...
# 118        Peter  Excellent battery life, noise cancelling isn't...
# 119     TJ Davis  I bought two pairs of these headphones. One fo...
#
#             User Rating         Color
# 115  4.0 out of 5 stars   Color: Blue
# 116  5.0 out of 5 stars  Color: Black
# 117  5.0 out of 5 stars   Color: Blue
# 118  5.0 out of 5 stars   Color: Blue
# 119  2.0 out of 5 stars  Color: Black

# %% [markdown]
# ### Page 28

# %%
url28 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=28'

#connect to website
response28 = requests.get(url28, headers = header)
soup28 = BeautifulSoup(response28.content, 'html.parser')

# %%
#storing required data in the variable
reviews28 = soup28.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews28:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews28 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews28.tail(5)
# Out:
#              Username                                             Review  \
# 125          MajJaz42  Sounds great, pretty good battery life. I've g...
# 126   Amazon Customer                                            Ta good
# 127  Jennifer J Radke  My every day headphones are apple earbuds but ...
# 128         Victor L.               Would work great in car or airplane!
# 129            Apollo  The q35 is excellent in bluetooth mode and all...
#
#             User Rating         Color
# 125  4.0 out of 5 stars   Color: Blue
# 126  5.0 out of 5 stars  Color: Black
# 127  2.0 out of 5 stars   Color: Blue
# 128  5.0 out of 5 stars   Color: Blue
# 129  4.0 out of 5 stars   Color: Blue

# %% [markdown]
# ### Page 29

# %%
url29 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=29'

#connect to website
response29 = requests.get(url29, headers = header)
soup29 = BeautifulSoup(response29.content, 'html.parser')

# %%
#storing required data in the variable
reviews29 = soup29.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews29:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews29 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews29.tail(5)
# Out:
#             Username                                             Review  \
# 135  Robert Porcella                No negatives with these headphones.
# 136     Kevin Urrego  Un producto calidad precio sin duda alguna, el...
# 137             KDJD  Before I being, I would like to say Soundcore ...
# 138        Steves V.  Pauses audio randomly and automatically.  Supe...
# 139          Russell  I'm impressed with the quality of the headphon...
#
#             User Rating         Color
# 135  5.0 out of 5 stars  Color: Black
# 136  5.0 out of 5 stars   Color: Blue
# 137  3.0 out of 5 stars   Color: Blue
# 138  3.0 out of 5 stars   Color: Blue
# 139  5.0 out of 5 stars  Color: Black

# %% [markdown]
# ### Page 30

# %%
url30 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=30'

#connect to website
response30 = requests.get(url30, headers = header)
soup30 = BeautifulSoup(response30.content, 'html.parser')

# %%
#storing required data in the variable
reviews30 = soup30.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews30:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews30 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews30.tail(5)
# Out:
#              Username                                             Review  \
# 145           Andy Mc  These headphones check the boxes on almost eve...
# 146  S M SHIBLY SADIK  It sounds somewhat to same level of Sony or Bo...
# 147       Photo Chick  Best noise cancellation (speakers / mic) and s...
# 148        Ironsights  My grandsons all have bose and still borrow mi...
# 149             Jason  Bought both the Sony WH-1000XM4 and these duri...
#
#             User Rating         Color
# 145  5.0 out of 5 stars   Color: Blue
# 146  4.0 out of 5 stars  Color: Black
# 147  5.0 out of 5 stars   Color: Blue
# 148  5.0 out of 5 stars   Color: Blue
# 149  4.0 out of 5 stars   Color: Blue

# %%
#save file to csv
reviews30 = reviews30.to_csv('reviews30.csv', index = True)

# %% [markdown]
# ### Page 31

# %%
url31 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=31'

#connect to website
response31 = requests.get(url31, headers = header)
soup31 = BeautifulSoup(response31.content, 'html.parser')

# %%
#storing required data in the variable
reviews31 = soup31.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews31:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews31 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews31.tail(5)
# Out:
#           Username                                             Review  \
# 155     Scott Graf  These fit my head just fine, but every head is...
# 156  Kevin McGrath  These were a gift to myself and I haven't had ...
# 157             Ed         Clear sound, we’ll balanced for the price.
# 158           Mike  The packaging/presentation was great, app good...
# 159        Scott S  I purchased these to replace some JBL headphon...
#
#             User Rating         Color
# 155  5.0 out of 5 stars  Color: Black
# 156  4.0 out of 5 stars   Color: Blue
# 157  4.0 out of 5 stars  Color: Black
# 158  3.0 out of 5 stars   Color: Blue
# 159  4.0 out of 5 stars   Color: Blue

# %% [markdown]
# ### Page 32

# %%
url32 = 'https://www.amazon.com/Soundcore-Cancelling-Headphones-Bluetooth-Comfortable/product-reviews/B09FPCZ318/\
ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=32'

#connect to website
response32 = requests.get(url32, headers = header)
soup32 = BeautifulSoup(response32.content, 'html.parser')

# %%
#storing required data in the variable
reviews32 = soup32.findAll('div', attrs = {'class':'a-section celwidget'})

for review in reviews32:
    user =  getattr(review.a.find('span', class_ = 'a-profile-name'), 'text', None)
    username.append(user)
    
    details = getattr(review.find('div', class_ = 'a-row a-spacing-small review-data'), 'text', None).replace('\n','')
    review_details.append(details)
    
    rating = getattr(review.find('span', class_ = 'a-icon-alt'), 'text', None)
    ratings.append(rating)
    
    color = getattr(review.find('a', class_ = 'a-size-mini a-link-normal a-color-secondary'), 'text', None)
    colour.append(color)
    
#store results in a dataframe
reviews32 = pd.DataFrame({'Username': username, 'Review': review_details, 'User Rating': ratings, 'Color': colour})
reviews32.tail(5)
# Out:
#                Username                                             Review  \
# 165              KayBee  Everything came as stated, headphones, case, a...
# 166   Charles Schneider  Good headphones for the price. Not crazy loud ...
# 167  Alexander Padalino  I have had these headphones for about a week n...
# 168                Ravi   Excellent for sound. Noise canceling is average.
# 169       Shawn Pacarar  Let me start by saying I do like these headpho...
#
#             User Rating         Color
# 165  5.0 out of 5 stars   Color: Blue
# 166  4.0 out of 5 stars  Color: Black
# 167  2.0 out of 5 stars   Color: Blue
# 168  3.0 out of 5 stars   Color: Blue
# 169  3.0 out of 5 stars   Color: Blue

# %%
#save file to csv
reviews32 = reviews32.to_csv('reviews32.csv', index = True)
